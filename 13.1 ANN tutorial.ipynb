# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from preamble import *

# %%
X,y = make_moons(n_samples=100,noise=0.25,random_state = 3)
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y, random_state = 42)#stratify = y비율로 나눔
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
# Out:
# ...
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
mlp = MLPClassifier(solver = 'lbfgs',random_state = 0).fit(X_train,y_train) #fit

mglearn.plots.plot_2d_separator(mlp,X_train,fill = True,alpha = .3)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
mlp = MLPClassifier(solver = 'lbfgs',random_state = 0,hidden_layer_sizes = [10]).fit(X_train,y_train)

mglearn.plots.plot_2d_separator(mlp,X_train,fill = True,alpha = .3)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
#10개의 유닛으로 된 두개의 은닉층 - hidden layer 두개
#레이어 많아질수록 복잡해진다 -> train data에는 잘맞으나 overfitting
mlp = MLPClassifier(solver = 'lbfgs',random_state = 0,hidden_layer_sizes = [10,10]).fit(X_train,y_train)

mglearn.plots.plot_2d_separator(mlp,X_train,fill = True,alpha = .3)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
# tanh 활성화 함수가 적용된 10개의 유닛으로 된 두개의 은닉층
mlp = MLPClassifier(solver = 'lbfgs',activation='tanh',random_state = 0,hidden_layer_sizes = [10,10]).fit(X_train,y_train)

mglearn.plots.plot_2d_separator(mlp,X_train,fill = True,alpha = .3)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
fig, axes = plt.subplots(2,4,figsize=(20,8))
for axx, n_hidden_nodes in zip(axes,[10,100]):
    for ax, alpha in zip(axx,[0.0001,0.01,0.1,1]): #알파값이 다를때, 히든레이어가 다를때
        mlp = MLPClassifier(solver = 'lbfgs',random_state = 0,hidden_layer_sizes=[n_hidden_nodes,n_hidden_nodes],alpha = alpha).fit(X_train,y_train)
        mglearn.plots.plot_2d_separator(mlp,X_train,fill = True,alpha = .3,ax=ax)
        mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train,ax = ax)
        ax.set_title("n_hidden = [{},{}]\nalpha={:.4f}".format(n_hidden_nodes,n_hidden_nodes,alpha))
    
#모델이 위가 더 간단하고 밑이 더 복잡 알파값이 커질수록 일반화가 심함
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
cancer = load_breast_cancer()
print(cancer.data.shape)
print(cancer.target.shape)
print("유방암 데이터의 특성별 최대값:\n",cancer.data.max(axis = 0))
# Out:
# (569, 30)
# (569,)
# 유방암 데이터의 특성별 최대값:
#  [  28.11    39.28   188.5   2501.       0.163    0.345    0.427    0.201
#     0.304    0.097    2.873    4.885   21.98   542.2      0.031    0.135
#     0.396    0.053    0.079    0.03    36.04    49.54   251.2   4254.
#     0.223    1.058    1.252    0.291    0.664    0.207]

# %%
X_train,X_test,y_train,y_test = train_test_split(cancer.data,cancer.target,random_state = 0)
mlp = MLPClassifier(random_state = 42)
mlp.fit(X_train,y_train)

print("훈련 세트 정확도: {:.2f}".format(mlp.score(X_train,y_train)))
print("테스트 세트 정확도: {:.2f}".format(mlp.score(X_test,y_test)))
# Out:
# 훈련 세트 정확도: 0.94
# 테스트 세트 정확도: 0.92

# %%
#평균 0, 분산 1을 갖도록 스케일 조정
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
mlp = MLPClassifier(random_state = 0)
mlp.fit(X_train_scaled,y_train)

print("훈련 세트 정확도: {:.3f}".format(mlp.score(X_train_scaled,y_train)))
print("테스트 세트 정확도: {:.3f}".format(mlp.score(X_test_scaled,y_test)))
# Out:
# 훈련 세트 정확도: 0.991
# 테스트 세트 정확도: 0.965
# C:\anaco\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp = MLPClassifier(max_iter = 1000,random_state = 0)
mlp.fit(X_train_scaled,y_train)

print("훈련 세트 정확도: {:.3f}".format(mlp.score(X_train_scaled,y_train)))
print("테스트 세트 정확도: {:.3f}".format(mlp.score(X_test_scaled,y_test)))
# Out:
# 훈련 세트 정확도: 1.000
# 테스트 세트 정확도: 0.972

# %%
#알파를 높여 훈련세트와 테스트세트의 간격을 좁힘 일반화를 더 함
mlp = MLPClassifier(max_iter = 1000,alpha = 1,random_state = 0)
mlp.fit(X_train_scaled,y_train)

print("훈련 세트 정확도: {:.3f}".format(mlp.score(X_train_scaled,y_train)))
print("테스트 세트 정확도: {:.3f}".format(mlp.score(X_test_scaled,y_test)))
# Out:
# 훈련 세트 정확도: 0.988
# 테스트 세트 정확도: 0.972

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

print(mlp.coefs_[0].shape)
print(mlp.coefs_[1].shape)
plt.figure(figsize = (20,5))
plt.imshow(mlp.coefs_[0])
plt.yticks(range(30),cancer.feature_names)
plt.xlabel("hidden unit")
plt.ylabel("input feature")
plt.colorbar()
# Out:
# (30, 100)
# (100, 1)
